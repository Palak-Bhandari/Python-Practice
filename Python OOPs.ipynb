# %%
# A simple program to demonstrate OOPs concepts in Python with help of a restaurants functionings.       
class Order():
    def __init__(self,dish):
        self.dish=dish
        
    def showmenu(self):          # Shows the menu of the retaurant
        print(self.dish)
        
    def menuadd(self):           # Adds dishes or edits the prices of a dish
        x=input('Enter the dish code you want to add or edit: ')
        price=int(input('Enter the new  price of the dish: '))
        self.dish[x]=price
        
    def read(self,e,order):       # Takes dishes customers wants to order 
        self.e=e
        self.order=order
        for i in range(e):
            i=input('Enter the dish code you wish to order: ')
            if i in self.dish:
                order[i]=self.dish[i]
            else:
                print('Your desired dish is not available.Sorry for inconvenience!')
                
    def display(self):            # Displays the order placed by the customer
        print('Your order is: ',self.order) 
        
    def bill(self,sum):           # Calculates total bill of the dishes ordered
        self.sum=sum
        for i in self.order:
            sum=sum+self.order[i]
        print('Your total bill is: ', sum)
        
    def check(self,key):         # Checking price of a particular dish 
        self.key=key
        if key in self.dish:
            print('The price for the dish is: ', self.dish[key])
        else:
            print('Your desired dish is not available. Sorry for inconvenience.')   
            
o = Order({'101':20,'102':25,'103':15,'103':25,'104':30,'105':20,'106':20})
password='manager@123'     # Password for manager
while(1):                  # Choosing your role - Menu driven
    print('1: Customer')
    print('2: Manager')
    print('3: Exit')
    option=int(input('What is your role? '))
    print()
    if option==1: 
        while(1):            # Choosing action to be performed as a customer - Menu Driven
            print('1: Menu')
            print('2: Give my order')
            print('3: Show my order')
            print('4: Show Total bill')
            print('5: Search for dish')
            print('6: Exit')
            choice=int(input('Enter your choice: '))
            print()
            if choice==1:
                o.showmenu()
                print()
            elif choice==2:
                o.read(int(input('Enter the number of total dishes you want to order: ')),{})
                print()
            elif choice==3:
                o.display()
                print()
            elif choice==4:
                o.bill(0)
                print()
            elif choice==5:
                o.check(input('Enter the dish code to check the price: '))
                print()
            elif choice==6:
                break
            else:
                print('Enter the correct choice!!')
                print()
    elif option==2:
        security=input('Enter the password: ')
        if security==password:
            while(1):           # Choosing action to be performed as Manager - Menu Driven
                print('1: Show menu')
                print('2: Add or edit the menu')
                print('3: Exit')
                choice=int(input('Enter your choice: '))
                print()
                if choice==1:
                    o.showmenu()
                    print()
                elif choice==2:
                    o.menuadd()
                    print()
                elif choice==3:
                    break
                else:
                    print('Enter the correct choice!!')
                    print()
        else:
            print('Incorrect Password!')
            print()
    elif option==3:
        break
    else:
        print('Enter the correct choice!!!')
        print()
# Out:
# 1: Customer
# 2: Manager
# 3: Exit
# What is your role? 1
#
# 1: Menu
# 2: Give my order
# 3: Show my order
# 4: Show Total bill
# 5: Search for dish
# 6: Exit
# Enter your choice: 1
#
# {'101': 20, '102': 25, '103': 25, '104': 30, '105': 20, '106': 20}
#
# 1: Menu
# 2: Give my order
# 3: Show my order
# 4: Show Total bill
# 5: Search for dish
# 6: Exit
# Enter your choice: 2
#
# Enter the number of total dishes you want to order: 1
# Enter the dish code you wish to order: 102
#
# 1: Menu
# 2: Give my order
# 3: Show my order
# 4: Show Total bill
# 5: Search for dish
# 6: Exit
# Enter your choice: 3
#
# Your order is:  {'102': 25}
#
# 1: Menu
# 2: Give my order
# 3: Show my order
# 4: Show Total bill
# 5: Search for dish
# 6: Exit
# Enter your choice: 4
#
# Your total bill is:  25
#
# 1: Menu
# 2: Give my order
# 3: Show my order
# 4: Show Total bill
# 5: Search for dish
# 6: Exit
# Enter your choice: 6
#
# 1: Customer
# 2: Manager
# 3: Exit
# What is your role? 2
#
# ...
